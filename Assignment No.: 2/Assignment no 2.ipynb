# %%
import csv
f1 = open("/content/drive/MyDrive/Colab Notebooks/Booking.csv",'r')
Seat_no = []
Pick_up_point = []
Drop_point = []
Dates = []
Travelers = []
Traveler_company = {}
gender = {}

d1 = list(csv.reader(f1,delimiter = ','))
print("Booking Data:")
print(d1)
print("\n")

for i in range(len(d1)):
    Seat_no.append(d1[i][0])
    Travelers.append(d1[i][1])
    Pick_up_point.append(d1[i][4])
    Drop_point.append(d1[i][5])
    Dates.append(d1[i][3])
    Traveler_company.update({d1[i][0]:d1[i][2]})
    gender.update({d1[i][1]:d1[i][6]})

print("Seat No.:")
print(Seat_no)
print("\n")
print("Name of Travelers:")
print(Travelers)
print("\n")
print("Pick_up_Points:")
print(set(Pick_up_point))
print("\n")
print("Drop_Points:")
print(set(Drop_point))
print("\n")
print("Name of Traveler_companies:")
print(set(Traveler_company.values()))
print("\n")
print("Dates:")
print(set(Dates))
print("\n")
print("Travelers and thier gender:")
print(gender)
print("\n")


# Most People travel on Which date :
frequency = {}
for item in Dates:
    if item in frequency:
        frequency[item] = frequency[item]+1
    else:
        frequency[item] = 1
print("Frequency of Dates:")
print(frequency)

marklist=sorted(frequency.items(),key = lambda x:x[1],reverse=True)
sortdict = dict(marklist)
print(marklist)
print("The Most People travel on this date = ",list(sortdict.keys())[0], "; No. of Peeople is =",list(sortdict.values())[0])
print("\n")

# Finding Most Popular Traveler company and no. of its customer :
frequency = {}
for item in Traveler_company.values():
    if item in frequency:
        frequency[item] = frequency[item]+1
    else:
        frequency[item] = 1
print("Frequency of Traveler_company:")
print(frequency)

marklist=sorted(frequency.items(),key = lambda x:x[1],reverse=True)
sortdict = dict(marklist)
print(marklist)
print("The Most Popular Traveler company is",list(sortdict.keys())[0], "use",list(sortdict.values())[0],"times.")
print("\n")

# Finding Most People Travel from which place and thier no. :
frequency = {}
for item in Pick_up_point:
    if item in frequency:
        frequency[item] = frequency[item]+1
    else:
        frequency[item] = 1
print("Frequency of Pick_up_points:")
print(frequency)

marklist=sorted(frequency.items(),key = lambda x:x[1],reverse=True)
sortdict = dict(marklist)
print(marklist)
print("The Most People Travel from",list(sortdict.keys())[0], "and thier no. is =",list(sortdict.values())[0])
print("\n")

# Finding Most People Travel to reach which place and thier no. :
frequency = {}
for item in Drop_point:
    if item in frequency:
        frequency[item] = frequency[item]+1
    else:
        frequency[item] = 1
print("Frequency of Drop_points:")
print(frequency)

marklist=sorted(frequency.items(),key = lambda x:x[1],reverse=True)
sortdict = dict(marklist)
print(marklist)
print("The Most People Travel to reach",list(sortdict.keys())[0], "and thier no. is =",list(sortdict.values())[0])
print("\n")

# Calculating no. of Males and Femlaes Traveler.
male = 0
female = 0

for item in gender.keys():
    if gender[item] == "Male":
        male = male + 1
    else:
        female = female + 1

print("No. of Males Travel : ",male)
print("No. of Females Travel : ",female)

print("\n")
print("******************************* Thank You! ******************************")
# Out:
# Booking Data:
# [['P0001', 'Amol Popalghat', 'Nilesh Travels', '5/5/2023', 'Pune', 'Nagpur', 'Male'], ['P0002', 'Aniruddha Pande', 'Ganesh Travels', '10/5/2023', 'Mumbai', 'Latur', 'Male'], ['P0003', 'Siddhi Patil', 'Ram Travels', '5/5/2023', 'Nashik', 'Nagpur', 'Female '], ['P0004', 'Ayush Rewatkar', 'Gopal Travels', '5/5/2023', 'Sambhajinagar', 'Nashik', 'Male'], ['P0005', 'Prathmesh Lashkare', 'Nilesh Travels', '10/5/2023', 'Pune', 'Jalgoan', 'Male'], ['P0006', 'Tejashri Pandit', 'Nilesh Travels', '2/5/2023', 'Pune', 'Latur', 'Female'], ['P0007', 'Rohan Agrawal', 'Ram Travels', '4/5/2023', 'Pune', 'Sambhajinagar', 'Male'], ['P0008', 'Angniv Bora', 'Gopal Travels', '5/5/2023', 'Kolhapuar', 'Mumbai', 'Male'], ['P0009', 'Ragini Kale', 'Ganesh Travels', '4/5/2023', 'Nagpur', 'Pune', 'Female'], ['P0010', 'Balaji More', 'Nilesh Travels', '2/5/2023', 'Akola', 'Nagpur', 'Male']]
#
#
# Seat No.:
# ['P0001', 'P0002', 'P0003', 'P0004', 'P0005', 'P0006', 'P0007', 'P0008', 'P0009', 'P0010']
#
#
# Name of Travelers:
# ['Amol Popalghat', 'Aniruddha Pande', 'Siddhi Patil', 'Ayush Rewatkar', 'Prathmesh Lashkare', 'Tejashri Pandit', 'Rohan Agrawal', 'Angniv Bora', 'Ragini Kale', 'Balaji More']
#
#
# Pick_up_Points:
# {'Nagpur', 'Akola', 'Pune', 'Kolhapuar', 'Nashik', 'Sambhajinagar', 'Mumbai'}
#
#
# Drop_Points:
# {'Nagpur', 'Pune', 'Latur', 'Nashik', 'Sambhajinagar', 'Mumbai', 'Jalgoan'}
#
#
# Name of Traveler_companies:
# {'Gopal Travels', 'Ram Travels', 'Ganesh Travels', 'Nilesh Travels'}
#
#
# Dates:
# {'10/5/2023', '4/5/2023', '2/5/2023', '5/5/2023'}
#
#
# Travelers and thier gender:
# {'Amol Popalghat': 'Male', 'Aniruddha Pande': 'Male', 'Siddhi Patil': 'Female ', 'Ayush Rewatkar': 'Male', 'Prathmesh Lashkare': 'Male', 'Tejashri Pandit': 'Female', 'Rohan Agrawal': 'Male', 'Angniv Bora': 'Male', 'Ragini Kale': 'Female', 'Balaji More': 'Male'}
#
#
# Frequency of Dates:
# {'5/5/2023': 4, '10/5/2023': 2, '2/5/2023': 2, '4/5/2023': 2}
# [('5/5/2023', 4), ('10/5/2023', 2), ('2/5/2023', 2), ('4/5/2023', 2)]
# The Most People travel on this date =  5/5/2023 ; No. of Peeople is = 4
#
#
# Frequency of Traveler_company:
# {'Nilesh Travels': 4, 'Ganesh Travels': 2, 'Ram Travels': 2, 'Gopal Travels': 2}
# [('Nilesh Travels', 4), ('Ganesh Travels', 2), ('Ram Travels', 2), ('Gopal Travels', 2)]
# The Most Popular Traveler company is Nilesh Travels use 4 times.
#
#
# Frequency of Pick_up_points:
# {'Pune': 4, 'Mumbai': 1, 'Nashik': 1, 'Sambhajinagar': 1, 'Kolhapuar': 1, 'Nagpur': 1, 'Akola': 1}
# [('Pune', 4), ('Mumbai', 1), ('Nashik', 1), ('Sambhajinagar', 1), ('Kolhapuar', 1), ('Nagpur', 1), ('Akola', 1)]
# The Most People Travel from Pune and thier no. is = 4
#
#
# Frequency of Drop_points:
# {'Nagpur': 3, 'Latur': 2, 'Nashik': 1, 'Jalgoan': 1, 'Sambhajinagar': 1, 'Mumbai': 1, 'Pune': 1}
# [('Nagpur', 3), ('Latur', 2), ('Nashik', 1), ('Jalgoan', 1), ('Sambhajinagar', 1), ('Mumbai', 1), ('Pune', 1)]
# The Most People Travel to reach Nagpur and thier no. is = 3
#
#
# No. of Males Travel :  7
# No. of Females Travel :  3
#
#
# ******************************* Thank You! ******************************
